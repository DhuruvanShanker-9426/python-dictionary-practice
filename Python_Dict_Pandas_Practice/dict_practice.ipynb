# %%
student={
    "name" : "Dhuru",
    "age" : 21,
    "course" : "Data Science",
    "city" : "Coimbatore"
}
print(student)
# Out:
# {'name': 'Dhuru', 'age': 21, 'course': 'Data Science', 'city': 'Coimbatore'}

# %%
student.values()
# Out:
# dict_values(['Dhuru', 21, 'Data Science', 'Coimbatore'])

# %%
student['skills']=["Python", "SQL", "Power BI"]
student.items()
# Out:
# dict_items([('name', 'Dhuru'), ('age', 21), ('course', 'Data Science'), ('city', 'Coimbatore'), ('skills', ['Python', 'SQL', 'Power BI'])])

# %%
print(student['course'])
student['course']="AI and ML"
print(student['course'])
# Out:
# Data Science
# AI and ML

# %%
del student['city']

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'course', 'skills'])

# %%
for key in student:
    print(key)
# Out:
# name
# age
# course
# skills

# %%
for value in student.values():
    print(value)
# Out:
# Dhuru
# 21
# AI and ML
# ['Python', 'SQL', 'Power BI']

# %%
for key,value in student.items():
    print(key,':',value)
# Out:
# name : Dhuru
# age : 21
# course : AI and ML
# skills : ['Python', 'SQL', 'Power BI']

# %%
words = ["python", "sql", "python", "powerbi", "sql", "python"]
word_freq={}

# for i in words:
#     word_freq[i]=words.count(i)
for word in words:
    if word in word_freq:
        word_freq[word]+=1
    else:
        word_freq[word]=1
print(word_freq)
# Out:
# {'python': 3, 'sql': 2, 'powerbi': 1}

# %%
marks = {
    "Maths": 90,
    "Python": 95,
    "SQL": 85,
    "Power BI": 88
}

top_subject = max(marks, key=marks.get)

print(top_subject,':',marks[top_subject])
# Out:
# Python : 95

# %%
students = {
    "student1": {
        "name": "Dhuru",
        "age": 21,
        "course": "Data Science"
    },
    "student2": {
        "name": "Arun",
        "age": 22,
        "course": "Python"
    }
}

print(students["student1"]["name"])
print(students["student2"]["name"])
# Out:
# Dhuru
# Arun
